# %%
import itertools
import numpy as np
import torch
from grnewt import NewtonSummary, compute_Hg, nesterov_lrs

# %%
"""
P = 10
num_expes = 1000

dct_errors = {'torch eigh': 0.,
              'torch eig': 0.,
              'numpy eigh': 0.,
              'numpy eig': 0.,
              'torch eigh (float64)': 0.}

val = -1e-6
for i in range(num_expes):
    Hm = torch.randn(P, P)
    Hp = Hm.t() @ Hm
    Hd, Hu = torch.linalg.eigh(Hp)
    Hd[0] = val
    H = Hu @ Hd.diag() @ Hu.t()

    dct_errors['torch eigh'] += abs(torch.linalg.eigh(H).eigenvalues[0].item() - val) / num_expes
    dct_errors['torch eig'] += abs(torch.linalg.eig(H).eigenvalues.real.sort().values[0].item() - val) / num_expes
    dct_errors['numpy eigh'] += abs(np.linalg.eigh(H.numpy()).eigenvalues[0] - val) / num_expes
    dct_errors['numpy eig'] += abs(sorted(np.linalg.eig(H.numpy()).eigenvalues.real)[0] - val) / num_expes
    dct_errors['torch eigh (float64)'] += abs(torch.linalg.eigh(H.to(dtype = torch.float64)).eigenvalues[0].item() - val) / num_expes

for k, v in dct_errors.items():
    print(k, ':', v)
"""
# Out:
# "\nP = 10\nnum_expes = 1000\n\ndct_errors = {'torch eigh': 0.,\n              'torch eig': 0.,\n              'numpy eigh': 0.,\n              'numpy eig': 0.,\n              'torch eigh (float64)': 0.}\n\nval = -1e-6\nfor i in range(num_expes):\n    Hm = torch.randn(P, P)\n    Hp = Hm.t() @ Hm\n    Hd, Hu = torch.linalg.eigh(Hp)\n    Hd[0] = val\n    H = Hu @ Hd.diag() @ Hu.t()\n\n    dct_errors['torch eigh'] += abs(torch.linalg.eigh(H).eigenvalues[0].item() - val) / num_expes\n    dct_errors['torch eig'] += abs(torch.linalg.eig(H).eigenvalues.real.sort().values[0].item() - val) / num_expes\n    dct_errors['numpy eigh'] += abs(np.linalg.eigh(H.numpy()).eigenvalues[0] - val) / num_expes\n    dct_errors['numpy eig'] += abs(sorted(np.linalg.eig(H.numpy()).eigenvalues.real)[0] - val) / num_expes\n    dct_errors['torch eigh (float64)'] += abs(torch.linalg.eigh(H.to(dtype = torch.float64)).eigenvalues[0].item() - val) / num_expes\n\nfor k, v in dct_errors.items():\n    print(k, ':', v)\n"

# %%
S = 10

g = torch.randn(S)

Hm = torch.randn(S, S)
Hp = Hm.t() @ Hm
Hd, Hu = torch.linalg.eigh(Hp)
Hd[0] = -.000001
H = Hu @ Hd.diag() @ Hu.t()
print('torch eigh = ', torch.linalg.eigh(H).eigenvalues[0].item())
print('torch eig =', torch.linalg.eig(H).eigenvalues.real.sort().values[0].item())
print('numpy eigh =', np.linalg.eigh(H.numpy()).eigenvalues[0])
print('numpy eig =', sorted(np.linalg.eig(H.numpy()).eigenvalues.real)[0])
print('torch eigh (float64) =', torch.linalg.eigh(H.to(dtype = torch.float64)).eigenvalues[0].item())

order3_ = torch.randn(S).abs()
order3_[1] = 0

lrs, logs = nesterov_lrs(H, g, order3_)
print('lrs =', lrs)
print('logs:', logs)
# Out:
# torch eigh =  -3.6789199384656968e-06
# torch eig = -1.3899551731810789e-06
# numpy eigh = -9.01293e-07
# numpy eig = -9.35971e-07
# torch eigh (float64) = -9.012929823473555e-07
# lrs = tensor([ 0.7345,  0.8709,  1.0126, -2.0833,  0.8786, -0.0838,  0.2544, -0.1824,
#         -0.2629, -0.4058])
# logs: {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 3.987068402667878e-06, 'f(x0) > 0': True, 'x1': 3.0000119612052085, 'r': 1.0925892287595027, 'r_converged': True, 'found': True, 'time': 0.1318826675415039}

# %%
### Building test

def test_nesterov(S, mode_H = 'random', mode_order3_ = 'random', verbose = True):
    g = torch.randn(S)
    
    Hm = torch.randn(S, S)
    Hp = Hm.t() @ Hm
    Hd, Hu = torch.linalg.eigh(Hp)
    if mode_H == 'positive':
        pass
    elif mode_H == 'random':
        Hd.normal_()
    elif mode_H == 'small':
        Hd[0] = -1e-6
    else:
        raise NotImplementedError('')
    H = Hu @ Hd.diag() @ Hu.t()
    
    order3_ = torch.randn(S).abs()
    if mode_order3_ == 'random':
        pass
    elif mode_order3_ == 'zero':
        order3_[1] = 0.
    elif mode_order3_ == 'small':
        order3_[1] = 2e-5
    else:
        raise NotImplementedError('')
    
    lrs, logs = nesterov_lrs(H, g, order3_)
    #print('lrs =', lrs)
    if verbose:
        print('found: {}'.format(logs['found']))
        if logs['found']:
            print('    lrs =', lrs)
        if True:
            print('    logs =', logs)

    return lrs, logs

# %%
for P in [2, 5, 10, 20, 30, 50]:
    print('###################')
    print('##### P = {} #####'.format(P))
    print('###################')
    for i in range(5):
        #print('beginning')
        test_nesterov(P, mode_H = 'random', mode_order3_ = 'zero')
        #print('end')
    print('')
# Out:
# ###################
# ##### P = 2 #####
# ###################
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'not converged', 'found': False, 'time': 0.027151823043823242}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'not converged', 'found': False, 'time': 0.033498525619506836}
# found: True
#     lrs = tensor([ 0.2768, -1.4546])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': True, 'D_sing': True, 'x0': 0, 'f(x0) > 0': True, 'x1': 1.0, 'r': 0.23670992941673435, 'r_converged': True, 'found': True, 'time': 0.0014605522155761719}
# found: True
#     lrs = tensor([ 9.9558, 56.9457])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 7.597341458706787, 'f(x0) > 0': True, 'x1': 25.79202437612036, 'r': 8.62462193577644, 'r_converged': True, 'found': True, 'time': 0.003261566162109375}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'not converged', 'found': False, 'time': 0.031122446060180664}
#
# ###################
# ##### P = 5 #####
# ###################
# found: True
#     lrs = tensor([  35.2812, -206.1982,    5.0032,    1.9120,  -59.6652])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 25.503852270563094, 'f(x0) > 0': True, 'x1': 79.51155681168927, 'r': 26.55696983893805, 'r_converged': True, 'found': True, 'time': 0.006075143814086914}
# found: True
#     lrs = tensor([-4.8907, -0.3367,  2.2614, -0.8044,  0.2925])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 0.5886013232021635, 'f(x0) > 0': True, 'x1': 4.76580396960649, 'r': 1.8808433913252565, 'r_converged': True, 'found': True, 'time': 0.003301858901977539}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5546014874717723.0, 'f(x0) > 0': False, 'found': False, 'time': 0.005875349044799805}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1780366368118152.8, 'f(x0) > 0': False, 'found': False, 'time': 0.006415843963623047}
# found: True
#     lrs = tensor([-24.6994, -63.8992,  -7.7201,  33.8834, -17.3277])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 23.931005475805314, 'f(x0) > 0': True, 'x1': 24.931005475805314, 'r': 24.26690666577815, 'r_converged': True, 'found': True, 'time': 0.0028793811798095703}
#
# ###################
# ##### P = 10 #####
# ###################
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1.9160435806776268e+16, 'f(x0) > 0': False, 'found': False, 'time': 0.0032088756561279297}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5.003021918340492e+16, 'f(x0) > 0': False, 'found': False, 'time': 0.005382537841796875}
# found: True
#     lrs = tensor([ 7.9726e+00, -9.2492e+01,  2.1206e+01, -1.2185e+01,  3.0717e+01,
#         -1.8096e+01, -4.6942e-02,  1.5127e+02,  4.8724e+00, -1.9553e+00])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 34.25910188095365, 'f(x0) > 0': True, 'x1': 35.25910188095365, 'r': 34.83410808159808, 'r_converged': True, 'found': True, 'time': 0.002979278564453125}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 990969762016206.8, 'f(x0) > 0': False, 'found': False, 'time': 0.003999233245849609}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 605914824435352.8, 'f(x0) > 0': False, 'found': False, 'time': 0.00396728515625}
#
# ###################
# ##### P = 20 #####
# ###################
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5950283180472463.0, 'f(x0) > 0': False, 'found': False, 'time': 0.007943868637084961}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1852449954037221.0, 'f(x0) > 0': False, 'found': False, 'time': 0.005845785140991211}
# found: True
#     lrs = tensor([ 1.6113e+02,  5.7389e+05, -5.2264e+01, -1.0280e+02, -7.9923e+00,
#         -3.8717e+01, -2.1539e+03, -3.1804e+01, -2.1351e+04, -5.8441e+01,
#          1.3489e+04, -2.9205e+01,  2.0680e+02, -1.0585e+01, -2.1174e+01,
#          7.6799e+02, -9.6814e+00,  1.0475e+01, -1.2881e+03, -2.3590e+01])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 2237.431687255679, 'f(x0) > 0': True, 'x1': 2238.431687255679, 'r': 2237.565286099532, 'r_converged': True, 'found': True, 'time': 0.006579399108886719}
# found: True
#     lrs = tensor([ 1.6925e+01, -5.2136e+02,  2.8205e+01,  4.4436e-01, -2.3464e+01,
#         -1.1102e+01, -3.6246e+02,  8.6977e+00, -3.0255e+01, -1.0784e+02,
#          1.8525e+00, -9.8080e+00,  1.4623e+02,  5.5614e+00, -1.2970e+01,
#         -2.0289e-01,  2.0727e+02, -1.1989e+00, -2.9935e+00,  8.3662e-01])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 64.30575655839164, 'f(x0) > 0': True, 'x1': 65.30575655839164, 'r': 64.55188369444144, 'r_converged': True, 'found': True, 'time': 0.003265380859375}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5517829063644188.0, 'f(x0) > 0': False, 'found': False, 'time': 0.0062427520751953125}
#
# ###################
# ##### P = 30 #####
# ###################
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1.2802372998213548e+16, 'f(x0) > 0': False, 'found': False, 'time': 0.014330148696899414}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 4.145060216774397e+16, 'f(x0) > 0': False, 'found': False, 'time': 0.016944408416748047}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 3456186691213738.5, 'f(x0) > 0': False, 'found': False, 'time': 0.014834403991699219}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 3.957523060374834e+16, 'f(x0) > 0': False, 'found': False, 'time': 0.018046855926513672}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5557823396801445.0, 'f(x0) > 0': False, 'found': False, 'time': 0.011683940887451172}
#
# ###################
# ##### P = 50 #####
# ###################
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 5559015306520325.0, 'f(x0) > 0': False, 'found': False, 'time': 0.02825927734375}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1803097971424498.2, 'f(x0) > 0': False, 'found': False, 'time': 0.02360367774963379}
# found: False
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1.0076321751370173e+17, 'f(x0) > 0': False, 'found': False, 'time': 0.028551101684570312}
# found: True
#     lrs = tensor([-1.2616e+02, -1.7515e+04,  4.8132e+01, -3.6981e+01,  1.0869e+04,
#          5.8011e+00,  1.2366e+03,  6.3593e+01, -1.6127e+01,  1.5647e+04,
#         -3.7210e+01,  4.2170e+00, -1.8549e+00, -2.6699e+01, -1.7671e+02,
#          1.4776e+01, -3.7394e+00, -3.7817e+00, -1.7971e+03,  5.0783e-01,
#          4.3044e+01, -1.1635e+01,  2.4826e+03,  8.3863e+01, -1.1909e+00,
#         -6.4951e+02,  3.7393e+00, -1.0615e+01, -1.9397e+02,  2.2008e+00,
#         -1.0406e+00, -1.1912e+03,  8.4844e-01,  2.1929e+01, -2.2840e+01,
#         -5.3473e+01,  2.2873e+01, -1.9247e+01,  7.8774e+01, -1.0670e+00,
#          6.5641e+00, -1.1328e+01, -1.1761e+01, -2.5874e+02,  1.1236e-01,
#         -2.9061e+01, -1.1459e+02,  1.4399e+01,  3.6436e+02,  4.0525e+00])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 690.5931122854549, 'f(x0) > 0': True, 'x1': 691.5931122854549, 'r': 690.6327486080958, 'r_converged': True, 'found': True, 'time': 0.009306669235229492}
# found: True
#     lrs = tensor([-8.3468e+02, -2.4279e+05,  3.1189e+02,  6.0295e+00,  1.1114e+01,
#         -1.1480e+02, -3.0305e+01,  2.3212e+01, -9.5724e+01, -3.4131e+00,
#         -1.2125e+03,  2.0541e+02, -6.1101e+00, -5.5173e+03,  7.5553e+04,
#         -2.9107e+02, -8.9941e+02, -1.1742e+01,  1.3584e+01,  1.9051e+02,
#          1.0262e+03, -1.4458e+02,  3.5417e+01, -4.3989e+00,  1.6677e+01,
#          1.3576e+02, -1.5374e+02,  5.9925e-01,  4.4179e+02,  3.7026e+04,
#          2.0816e+01,  2.7719e+01,  1.0252e+01,  7.8729e+00,  7.5704e+02,
#          6.2747e+02,  6.7217e+03, -1.0304e+02, -1.0915e+01, -1.6647e+03,
#         -2.1375e+00,  6.5357e+00, -2.7828e+01, -1.5199e+02, -1.7748e+01,
#          4.2255e+01,  4.4125e+01, -6.3350e+01,  1.3292e+02,  2.2183e+01])
#     logs = {'small_eigs': True, 'do_float64': True, 'H_pd': False, 'D_sing': True, 'x0_numerical': 'converged', 'x0': 1701.5154982728204, 'f(x0) > 0': True, 'x1': 1702.5154982728204, 'r': 1701.6055036819685, 'r_converged': True, 'found': True, 'time': 0.010190248489379883}

# %%
num_expes = 200

for P in [2, 5, 10, 20, 30, 50]:
    print('###################')
    print('##### P = {} #####'.format(P))
    print('###################')
    for mode_H, mode_order3_ in itertools.product(['positive', 'random', 'small'], ['random', 'small', 'zero']):
        found = 0
        tot_time = 0.
        for i in range(num_expes):
            #print('beginning')
            lrs, logs = test_nesterov(P, mode_H = mode_H, mode_order3_ = mode_order3_, verbose = False)
            tot_time += logs['time']
            if logs['found']:
                found += 1
            #print('end')
        print('mode_H = {}, mode_order3_ = {}: {:.2%} success, {:.6f} seconds'.format(mode_H, mode_order3_, 
                                                                                      found / num_expes, tot_time))
    print('')
# Out:
# ###################
# ##### P = 2 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.489216 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.450472 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.265254 seconds
# mode_H = random, mode_order3_ = random: 100.00% success, 0.509266 seconds
# mode_H = random, mode_order3_ = small: 98.00% success, 0.419339 seconds
# mode_H = random, mode_order3_ = zero: 47.50% success, 2.225386 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.254981 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.263143 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.275708 seconds
#
# ###################
# ##### P = 5 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.322450 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.335235 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.204485 seconds
# mode_H = random, mode_order3_ = random: 100.00% success, 0.584339 seconds
# mode_H = random, mode_order3_ = small: 95.50% success, 0.382064 seconds
# mode_H = random, mode_order3_ = zero: 58.50% success, 0.484093 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.297116 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.291649 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.323932 seconds
#
# ###################
# ##### P = 10 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.387015 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.420101 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.283297 seconds
# mode_H = random, mode_order3_ = random: 99.00% success, 0.810472 seconds
# mode_H = random, mode_order3_ = small: 93.00% success, 0.445979 seconds
# mode_H = random, mode_order3_ = zero: 54.50% success, 0.651278 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.308391 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.291925 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.359338 seconds
#
# ###################
# ##### P = 20 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.514708 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.526501 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.258191 seconds
# mode_H = random, mode_order3_ = random: 100.00% success, 0.789207 seconds
# mode_H = random, mode_order3_ = small: 92.00% success, 0.497616 seconds
# mode_H = random, mode_order3_ = zero: 47.00% success, 0.831024 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.310774 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.330148 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.377155 seconds
#
# ###################
# ##### P = 30 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.699230 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.659918 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.306267 seconds
# mode_H = random, mode_order3_ = random: 100.00% success, 0.907688 seconds
# mode_H = random, mode_order3_ = small: 88.50% success, 0.532402 seconds
# mode_H = random, mode_order3_ = zero: 46.50% success, 1.499031 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.373155 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.395649 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.520714 seconds
#
# ###################
# ##### P = 50 #####
# ###################
# mode_H = positive, mode_order3_ = random: 100.00% success, 0.807332 seconds
# mode_H = positive, mode_order3_ = small: 100.00% success, 0.796737 seconds
# mode_H = positive, mode_order3_ = zero: 100.00% success, 0.387873 seconds
# mode_H = random, mode_order3_ = random: 99.50% success, 1.093994 seconds
# mode_H = random, mode_order3_ = small: 80.00% success, 0.628906 seconds
# mode_H = random, mode_order3_ = zero: 45.00% success, 2.456997 seconds
# mode_H = small, mode_order3_ = random: 100.00% success, 0.529820 seconds
# mode_H = small, mode_order3_ = small: 100.00% success, 0.508161 seconds
# mode_H = small, mode_order3_ = zero: 100.00% success, 0.624514 seconds
